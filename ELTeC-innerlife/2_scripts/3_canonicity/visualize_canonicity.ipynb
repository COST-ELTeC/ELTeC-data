# %%
# Imports

import pandas as pd
import plotly.express as px
import seaborn as sns
# Visualization
from matplotlib import pyplot as plt

# %%
# Clone reps
! git clone https://github.com/COST-ELTeC/ELTeC-deu.git
! git clone https://github.com/COST-ELTeC/ELTeC-eng.git
! git clone https://github.com/COST-ELTeC/ELTeC-spa.git 
! git clone https://github.com/COST-ELTeC/ELTeC-fra.git 
! git clone https://github.com/COST-ELTeC/ELTeC-por.git
! git clone https://github.com/COST-ELTeC/ELTeC-srp.git 
! git clone https://github.com/COST-ELTeC/ELTeC-hun.git
! git clone https://github.com/COST-ELTeC/ELTeC-nor.git
! git clone https://github.com/COST-ELTeC/ELTeC-rom.git
# Out:
# Cloning into 'ELTeC-deu'...
# remote: Enumerating objects: 2247, done.
# remote: Counting objects: 100% (659/659), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 2247 (delta 485), reused 633 (delta 462), pack-reused 1588
# Receiving objects: 100% (2247/2247), 375.73 MiB | 4.63 MiB/s, done.
# Resolving deltas: 100% (1805/1805), done.
# Updating files: 100% (311/311), done.
# Cloning into 'ELTeC-eng'...
# remote: Enumerating objects: 2942, done.
# remote: Counting objects: 100% (769/769), done.
# remote: Compressing objects: 100% (296/296), done.
# remote: Total 2942 (delta 582), reused 659 (delta 472), pack-reused 2173
# Receiving objects: 100% (2942/2942), 357.62 MiB | 3.36 MiB/s, done.
# Resolving deltas: 100% (2326/2326), done.
# Updating files: 100% (210/210), done.
# Cloning into 'ELTeC-spa'...
# remote: Enumerating objects: 1955, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 1955 (delta 2), reused 4 (delta 1), pack-reused 1946
# Receiving objects: 100% (1955/1955), 69.23 MiB | 4.99 MiB/s, done.
# Resolving deltas: 100% (1441/1441), done.
# Updating files: 100% (212/212), done.
# Cloning into 'ELTeC-fra'...
# remote: Enumerating objects: 6517, done.
# remote: Counting objects: 100% (665/665), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 6517 (delta 509), reused 659 (delta 504), pack-reused 5852
# Receiving objects: 100% (6517/6517), 181.27 MiB | 5.75 MiB/s, done.
# Resolving deltas: 100% (5225/5225), done.
# Updating files: 100% (308/308), done.
# Cloning into 'ELTeC-por'...
# remote: Enumerating objects: 3820, done.
# remote: Counting objects: 100% (345/345), done.
# remote: Compressing objects: 100% (171/171), done.
# remote: Total 3820 (delta 196), reused 207 (delta 168), pack-reused 3475
# Receiving objects: 100% (3820/3820), 410.91 MiB | 5.02 MiB/s, done.
# Resolving deltas: 100% (2875/2875), done.
# Updating files: 100% (224/224), done.
# Cloning into 'ELTeC-srp'...
# remote: Enumerating objects: 2394, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 2394 (delta 73), reused 64 (delta 62), pack-reused 2316
# Receiving objects: 100% (2394/2394), 232.23 MiB | 6.21 MiB/s, done.
# Resolving deltas: 100% (1697/1697), done.
# Updating files: 100% (214/214), done.
# Cloning into 'ELTeC-hun'...
# remote: Enumerating objects: 1189, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 1189 (delta 19), reused 130 (delta 19), pack-reused 1059
# Receiving objects: 100% (1189/1189), 169.75 MiB | 5.74 MiB/s, done.
# Resolving deltas: 100% (789/789), done.
# Updating files: 100% (207/207), done.
# Cloning into 'ELTeC-nor'...
# remote: Enumerating objects: 946, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 946 (delta 15), reused 40 (delta 13), pack-reused 902
# Receiving objects: 100% (946/946), 72.58 MiB | 5.57 MiB/s, done.
# Resolving deltas: 100% (677/677), done.
# Updating files: 100% (124/124), done.
# Cloning into 'ELTeC-rom'...
# remote: Enumerating objects: 3184, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 3184 (delta 44), reused 79 (delta 38), pack-reused 3091
# Receiving objects: 100% (3184/3184), 319.65 MiB | 5.56 MiB/s, done.
# Resolving deltas: 100% (2197/2197), done.
# Updating files: 100% (519/519), done.

# %%
def get_metadata(language: str):
    path = "ELTeC-" + language + "/ELTeC-" + language + "_metadata.tsv"
    df = pd.read_csv(path, sep="\t", encoding="utf-8")
    return df

def get_data(language: str):
    path = "ELTeC-data/" + language + "/manualCounts.dat"
    df = pd.read_csv(path, sep=" ", encoding="utf-8")
    df["anteil_innerVerbs"] = df["innerVerbs"]/df["verbs"]
    
    return df

def concatenate_dfs(metadata, data):
    df = pd.concat([metadata, data], axis=1, join="inner")
    return df

def plot_scatterplot(df, language):
    sns.lmplot(x="year", 
           y="anteil_innerVerbs", 
           hue="reprint-count",
           data=df,
           height=10)

    savename = "plots/" + language + ".png"
    plt.savefig(savename,format='png',dpi=150)
    #plt.show()

def main(language: str):
    metadata = get_metadata(language)
    data = get_data(language)
    
    df = concatenate_dfs(metadata,data)
    
    plot_scatterplot(df, language)

# %%
languages = ["deu", "eng", "spa", "fra", "por", "hun", "rom"] #"nor", "srp",

# %%
for language in languages:
    main(language)
